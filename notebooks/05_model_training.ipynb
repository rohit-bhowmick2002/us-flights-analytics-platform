# %% [markdown]
# # 05: Machine Learning Model Training (Classification & Regression)
#
# We train Random Forest and XGBoost classifiers to predict 15+ minute arrival delays and regressors to forecast exact delay duration.

# %%
import sys
sys.path.append('..')
from src.models.train import train_models

# Train pipelines and log validation scores
results = train_models()
print('Training Results Summary:')
print(results['class_metrics'])
print(results['reg_metrics'])
