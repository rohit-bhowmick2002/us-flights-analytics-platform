# %% [markdown]
# # 06: Model Evaluation, Explainability & Diagnostics
#
# We evaluate test set ROC curves, confusion matrices, and feature importances to explain what drives flight delays.

# %%
import sys
sys.path.append('..')
from src.models.evaluate import run_evaluation
from src.models.explainability import generate_feature_importance_plot

run_evaluation()
df_imp = generate_feature_importance_plot()
print(df_imp.head(10))
