# %% [markdown]
# # 01: Raw Data Exploration & Schema Audit
#
# In this notebook, we inspect the raw multi-table relational flight, weather, airport, and airline datasets from U.S. DOT and NOAA ASOS.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Set paths
RAW_DIR = Path('../data/raw')
flights = pd.read_csv(RAW_DIR / 'flights/flights_raw.csv')
weather = pd.read_csv(RAW_DIR / 'weather/weather_hourly.csv')
airports = pd.read_csv(RAW_DIR / 'airports/airports.csv')
airlines = pd.read_csv(RAW_DIR / 'airlines/airlines.csv')

print(f'Flights shape: {flights.shape}')
print(f'Weather shape: {weather.shape}')

# %%
flights.head()

# %%
flights.info()

# %%
weather.describe()
